# %%
import numpy as np #https://github.com/numpy/numpy 
import matplotlib.pyplot as plt #https://github.com/matplotlib/matplotlib
import scipy.stats as st #https://github.com/scipy/scipy
import pandas as pd #https://github.com/pandas-dev/pandas

# %%
df = pd.read_csv('bvk.csv')
df
# Out:
#    RECS_fid  AnrLat_deg  AnrdLon_deg  AnrAlt_m    Lat_deg    Lon_deg  Gtm_sec  \
# 0       141   27.975487    83.468221    459.31  27.975431  83.468216     5831
# 1       142   27.975487    83.468221    459.32  27.975431  83.468208     5832
# 2       143   27.975487    83.468221    459.32  27.975431  83.468201     5833
# 3       144   27.975487    83.468221    459.32  27.975431  83.468201     5834
# 4       145   27.975487    83.468221    459.32  27.975429  83.468193     5835
# 5       146   27.975487    83.468221    459.32  27.975428  83.468201     5836
# 6       147   27.975481    83.468232    459.31  27.975426  83.468201     5837
# 7       148   27.975478    83.468238    459.32  27.975426  83.468201     5838
# 8       149   27.975473    83.468245    459.33  27.975416  83.468193     5839
# 9       150   27.975468    83.468251    459.34  27.975410  83.468201     5840
#
#    GPSFix  Stl  Geos  ...  AE_MeV/s  Dose_nSvpH  cK_pct  cUr_ppm  cTh_ppm  \
# 0       2    5 -36.6  ...       0.0         0.0    10.0     20.0     30.0
# 1       2    4 -36.6  ...       0.0         0.0    10.0     20.0     30.0
# 2       2    4 -36.6  ...       0.0         0.0    10.0     20.0     30.0
# 3       2    4 -36.6  ...       0.0         0.0    10.0     20.0     30.0
# 4       2    4 -36.6  ...       0.0         0.0    10.0     20.0     30.0
# 5       2    4 -36.6  ...       0.0         0.0    10.0     20.0     30.0
# 6       2    4 -36.6  ...       0.0         0.0    10.0     20.0     30.0
# 7       2    4 -36.6  ...       0.0         0.0    10.0     20.0     30.0
# 8       2    5 -36.6  ...       0.0         0.0    10.0     20.0     30.0
# 9       2    5 -36.6  ...       0.0         0.0    10.0     20.0     30.0
#
#    cCs_kBqpm2  ISPS  Gain  Battery_V  Unnamed: 39
# 0        40.0     N   1.0       8.00          NaN
# 1        40.0     N   1.0       7.99          NaN
# 2        40.0     N   1.0       8.00          NaN
# 3        40.0     N   1.0       7.99          NaN
# 4        40.0     N   1.0       7.99          NaN
# 5        40.0     N   1.0       7.99          NaN
# 6        40.0     N   1.0       7.99          NaN
# 7        40.0     N   1.0       8.00          NaN
# 8        40.0     N   1.0       7.99          NaN
# 9        40.0     N   1.0       7.99          NaN
#
# [10 rows x 40 columns]
